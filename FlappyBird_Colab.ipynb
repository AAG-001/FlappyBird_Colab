# %% [markdown]
# <a href="https://colab.research.google.com/github/AAG-001/FlappyBird_Colab/blob/master/FlappyBird_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/yenchenlin/DeepLearningFlappyBird.git
# Out:
# Cloning into 'DeepLearningFlappyBird'...
# remote: Enumerating objects: 246, done.
# remote: Total 246 (delta 0), reused 0 (delta 0), pack-reused 246
# Receiving objects: 100% (246/246), 66.29 MiB | 37.17 MiB/s, done.
# Resolving deltas: 100% (121/121), done.

# %%
# !pip install pygame
# Out:
# ...
#      |████████████████████████████████| 11.4MB 364kB/s
# ...

# %%
# !python DeepLearningFlappyBird/deep_q_network.py
# Out:
# Streaming output truncated to the last 5000 lines.
# TIMESTEP 4009 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX 1.255210e-02
# TIMESTEP 4010 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX 1.255210e-02
# TIMESTEP 4011 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX 1.255210e-02
# TIMESTEP 4012 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX 1.255210e-02
# TIMESTEP 4013 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX 1.255210e-02
# TIMESTEP 4014 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX 1.255210e-02
# TIMESTEP 4015 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX 1.255210e-02
# TIMESTEP 4016 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX 1.255210e-02
# TIMESTEP 4017 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX 1.255210e-02
# TIMESTEP 4018 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX 1.255210e-02
# ...
